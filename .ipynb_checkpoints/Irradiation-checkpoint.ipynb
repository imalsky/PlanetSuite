# %%
##############################################
########     Radius Irradiation   ############
###############################################
import numpy as np
import matplotlib.pyplot as plt
from scipy import loadtxt, optimize
import os
import sys
import os.path
import os.path
import shutil
# %matplotlib notebook
from scipy import loadtxt, optimize
from collections import defaultdict
from scipy.interpolate import interp1d

#mpList=[1,5,10]
mpList=[5]
enFracList=[.0025,.005,.0075,.01,.05,.10]
yList = [.24]
zList = [.02]
orbitalList=[.05,.1,.15,.2,.25,.3,.35,.4,.45,.5,.55,.6,.65,.7,.75,.8,.85,.9,.95,1.0]
entropyList = [9.0]
n_frac_list = [.05]  

#mpList = [19.37]
#Iterate again over all the files
#Iterate again over all the files
base_path = '/Users/isaacmalsky/Desktop/LOGS/evolve_'
flux_list = []
rad_list = []

enFrac_list = []
metalicity_list = []
hydrogen_list = []
helium_list = []
envelope_mass = []

for zfrac in zList:
    for enFrac in enFracList:
        for yfrac in yList:
            for entropy in entropyList:
                for orb_sep in orbitalList:
                    for mp in mpList:
                        for n_frac in n_frac_list:              
                            myfile = ''
                            extension = "{}_{}_{}_{}_{}_{}_{}".format(mp,enFrac,yfrac,zfrac,orb_sep,entropy, n_frac)
                            myfile = base_path + extension + ".mod"                     

                            if (os.path.isfile(myfile)):
                                x,y,hydrogen, helium, hydrogen_mass, helium_mass = loadtxt(myfile, unpack=True, skiprows =6, usecols=[0,14,22,24,17,18])
                                y = y / (637.1 * 10 ** 6)
                                earth_flux = (5.67e-5*5700**4 * (.464*6.9598e10 / 1 /1.496e13)**2)*(1-.3)
                                flux_dayside = (5.67e-5*6000**4 * (.464*6.9598e10/orb_sep /1.496e13)**2)*(1-.2) / earth_flux


                                array_type = str(type(x))
                                if (array_type == "<class 'numpy.ndarray'>"):
                                    print (x[-1])
                                    if (x[-1] > 9.698):
                                        #print (hydrogen[-1],helium[-1], (1 - hydrogen[-1] - helium[-1]))

                                        age_radius = interp1d(x,y)
                                        flux_list.append(float(flux_dayside))
                                        rad_list.append(float(age_radius(9.698)))
                                        enFrac_list.append(enFrac)                                  

                                        metalicity_list.append(1 - hydrogen[-1] - helium[-1])
                                        hydrogen_list.append(hydrogen[-1])
                                        helium_list.append(helium[-1])
                                        envelope_mass.append((hydrogen_mass[-1] + helium_mass[-1]) / (hydrogen_mass[0] + helium_mass[0]))
# Out:
# 6.78176987197
# 7.35267757391
# 6.90246907111
# 7.11081702685
# 7.49045638794
# 8.76242560751
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 6.78418457419
# 7.93216158121
# 6.96646087869
# 7.32595060376
# 8.12513481553
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 6.78554655136
# 8.62890677638
# 7.16043198849
# 7.48609591126
# 8.88565412848
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 6.78673675675
# 9.73461224789
# 7.02858861491
# 7.60533453178
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 6.77956123984
# 10.0
# 7.13944813716
# 8.14364651501
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 6.77848463981
# 10.0
# 7.11425086281
# 7.96048263228
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

                       
x = flux_list
y = rad_list

#t = enFrac_list
#t = metalicity_list
#t = hydrogen_list
t = helium_list
#t = envelope_mass

plt.scatter(x, y, c=t, cmap="jet_r")
plt.colorbar()

#plt.xscale('log')
plt.xlabel('Flux Relative to Earth')
plt.ylabel('Radius at 5 billion years ($R_{\oplus}$)')

#plt.axis([0,7,0, 2.5])
plt.gca().invert_xaxis()


plt.show()
#plt.savefig('/Users/isaacmalsky/Desktop/Test1.pdf',dpi=400)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# Out:
# 321.8934888776382

# %%
import numpy as np
import matplotlib.pyplot as plt

b = 3.88
c = 2.07
d = 1.043
e = .604
f = .349
g = .236
h = .135

plt.errorbar(b, 1.127 ,yerr=0.028, xerr= 0.22,fmt='.', color='black')
plt.errorbar(c, 1.1 ,yerr=.028, xerr= 0.12,fmt='.', color='black')
plt.errorbar(d, .788 ,yerr=0.02, xerr= 0.06,fmt='.', color='black')
plt.errorbar(e, .915 ,yerr=0.025, xerr= 0.034,fmt='.', color='black')
plt.errorbar(f, 1.052 ,yerr=.026, xerr= .020,fmt='.', color='black')
plt.errorbar(g, 1.154 ,yerr=0.029, xerr= 0.014,fmt='.', color='black')
plt.errorbar(h, .777 ,yerr=0.025, xerr= 0.076,fmt='.', color='black')


#plt.xscale('log')
plt.xlabel('Flux $[S_{earth}]$')
plt.ylabel('Planet Radius $[R_\oplus]$')
plt.title('Irraditaion of the TRAPPIST 1 System')

plt.axis([-.5,4.5,0, 1.75])
plt.gca().invert_xaxis()




plt.savefig('/Users/isaacmalsky/Desktop/Trappist1.png',dpi=300)

plt.show()
