# %%
##############################################
########     Radius Irradiation   ############
###############################################
import numpy as np
import matplotlib.pyplot as plt
from scipy import loadtxt, optimize
import os
import sys
import os.path
import os.path
import shutil
# %matplotlib notebook
from scipy import loadtxt, optimize
from collections import defaultdict
from scipy.interpolate import interp1d

mpList=[5]
enFracList = [0.001  ,  0.00245,  0.0039 ,  0.00535,  0.0068 ,  0.00825,
        0.0097 ,  0.01115,  0.0126 ,  0.01405,  0.0155 ,  0.01695,
        0.0184 ,  0.01985,  0.0213 ,  0.02275,  0.0242 ,  0.02565,
        0.0271 ,  0.02855,  0.03]
yList = [.24]
zList = [.02]
orbitalList = [ 0.05  ,  0.0975,  0.145 ,  0.1925,  0.24  ,  0.2875,  0.335 ,
        0.3825,  0.43  ,  0.4775,  0.525 ,  0.5725,  0.62  ,  0.6675,
        0.715 ,  0.7625,  0.81  ,  0.8575,  0.905 ,  0.9525,  1.    ]
entropyList = [9.0]
n_frac_list = [.05, .10]

#mpList = [19.37]
#Iterate again over all the files
#Iterate again over all the files
base_path = '/Users/isaacmalsky/Desktop/5/LOGS/evolve_'
flux_list1 = []
rad_list1 = []
helium_list1 = []

flux_list2 = []
rad_list2 = []
helium_list2 = []

flux_list3 = []
rad_list3 = []
helium_list3 = []

flux_list4 = []
rad_list4 = []
helium_list4 = []

flux_list5 = []
rad_list5 = []
helium_list5 = []

flux_list6 = []
rad_list6 = []
helium_list6 = []

flux_list7 = []
rad_list7 = []
helium_list7 = []


enFrac_list = []
metalicity_list = []
hydrogen_list = []
envelope_mass = []

for zfrac in zList:
    for enFrac in enFracList:
        for yfrac in yList:
            for entropy in entropyList:
                for orb_sep in orbitalList:
                    for mp in mpList:
                        for n_frac in n_frac_list:              
                            myfile = ''
                            extension = "{}_{}_{}_{}_{}_{}_{}".format(mp,enFrac,yfrac,zfrac,orb_sep,entropy, n_frac)
                            myfile = base_path + extension + ".mod"                     

                            if (os.path.isfile(myfile)):
                                x,y,hydrogen, helium, hydrogen_mass, helium_mass = loadtxt(myfile, unpack=True, skiprows =6, usecols=[0,14,22,24,17,18])
                                y = y / (637.1 * 10 ** 6)
                                earth_flux = (5.67e-5*5700**4 * (.464*6.9598e10 / 1 /1.496e13)**2)*(1-.3)
                                flux_dayside = (5.67e-5*6000**4 * (.464*6.9598e10/orb_sep /1.496e13)**2)*(1-.2) / earth_flux


                                array_type = str(type(x))
                                if (array_type == "<class 'numpy.ndarray'>"):
                                    if (x[-1] > 9.):
                                        age_radius = interp1d(x,y)
                                        if (mp == 2.5):
                                            flux_list1.append(float(flux_dayside))
                                            rad_list1.append(float(age_radius(9.)))
                                            helium_list1.append(helium[-1])
                                            
                                        if (mp == 5):
                                            flux_list2.append(float(flux_dayside))
                                            rad_list2.append(float(age_radius(9.)))
                                            helium_list2.append(helium[-1])
                                            
                                            
                                        if (mp == 7.5):
                                            flux_list3.append(float(flux_dayside))
                                            rad_list3.append(float(age_radius(9.)))
                                            helium_list3.append(helium[-1])     
                                            
                                            
                                        if (mp == 10):
                                            flux_list4.append(float(flux_dayside))
                                            rad_list4.append(float(age_radius(9.)))
                                            helium_list4.append(helium[-1])     
                                            
                                            
                                        if (mp == 15):
                                            flux_list5.append(float(flux_dayside))
                                            rad_list5.append(float(age_radius(9.)))
                                            helium_list5.append(helium[-1])                                            
                                            
                                            
                                        if (mp == 20):
                                            flux_list6.append(float(flux_dayside))
                                            rad_list6.append(float(age_radius(9.)))
                                            helium_list6.append(helium[-1])
                                            
                                        if (mp == 25):
                                            flux_list7.append(float(flux_dayside))
                                            rad_list7.append(float(age_radius(9.)))
                                            helium_list7.append(helium[-1])           
                                            
                                            
                                            
                                            
print (flux_list1) 
print ()
print (flux_list2)  
print ()
print (flux_list3)   
print ()
print (flux_list4)   
print ()
print (flux_list5)   
print ()
print (flux_list6)   
print ()
print (flux_list7)
# Out:
# []
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

                       
x = flux_list
y = rad_list

#t = enFrac_list
#t = metalicity_list
#t = hydrogen_list
t = helium_list
#t = envelope_mass

t.append(0)
t.append(1)
x.append(-1000)
x.append(-1000)
y.append(-1000)
y.append(-1000)

plt.scatter(x, y, c=t, cmap="jet_r")
plt.colorbar()

#plt.xscale('log')
#plt.xlabel('Flux Relative to Earth')
#plt.ylabel('Radius at 3 billion years ($R_{\oplus}$)')

#plt.axis([0,160,1.5, 3])
#plt.gca().invert_xaxis()


plt.show()
#plt.savefig('/Users/isaacmalsky/Desktop/10billion.pdf',dpi=400)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     140     try:
# --> 141         rgba = _colors_full_map.cache[c, alpha]
#     142     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: (0.85474189883381035, None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-305-b5ac71ae065f> in <module>()
#      20 y.append(-1000)
#      21
# ---> 22 plt.scatter(x, y, c=t, cmap="jet_r")
#      23 plt.colorbar()
#      24
#
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
# ...

# %%
from numpy.random import uniform, seed
from matplotlib.mlab import griddata
#from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import seaborn as sns; sns.set()

sns.set_style("darkgrid")
sns.set_context("talk")
sns.cubehelix_palette(as_cmap=True, reverse=True)


#x1 = flux_list1
#y1 = rad_list1
#z1 = helium_list1
#np.asarray(x1)
#np.asarray(y1)
#np.asarray(z1)
#xi1 = np.linspace(5, 190, len(x1))
#yi1 = np.linspace(2.2, 2.8, len(y1))
#zi1 = mlab.griddata(x1, y1, z1, xi1, yi1, interp='linear')

x2 = flux_list2
y2 = rad_list2
z2 = helium_list2
np.asarray(x2)
np.asarray(y2)
np.asarray(z2)
xi2 = np.linspace(7.5, 15, 10*len(x2))
yi2 = np.linspace(1.6, 2.00, 10*len(y2))
zi2 = griddata(x2, y2, z2, xi2, yi2, interp='linear')

"""
x3 = flux_list3
y3 = rad_list3
z3 = helium_list3
np.asarray(x3)
np.asarray(y3)
np.asarray(z3)
xi3 = np.linspace(8.5, 35, 10*len(x3))
yi3 = np.linspace(1.6, 2.3, 10*len(y3))
zi3 = griddata(x3, y3, z3, xi3, yi3, interp='linear')

x4 = flux_list4
y4 = rad_list4
z4 = helium_list4
np.asarray(x4)
np.asarray(y4)
np.asarray(z4)
xi4 = np.linspace(0, 100, 10*len(x4))
yi4 = np.linspace(1.8, 2.4, 10*len(y4))
zi4 = griddata(x4, y4, z4, xi4, yi4, interp='linear')


x5 = flux_list5
y5 = rad_list5
z5 = helium_list5
np.asarray(x5)
np.asarray(y5)
np.asarray(z5)
xi5 = np.linspace(5, 100, 10*len(x5))
yi5 = np.linspace(1.5, 2.6, 10*len(y5))
zi5 = griddata(x5, y5, z5, xi5, yi5, interp='linear')




x6 = flux_list6
y6 = rad_list6
z6 = helium_list6
np.asarray(x6)
np.asarray(y6)
np.asarray(z6)
xi6 = np.linspace(0, 160, 10*len(x6))
yi6 = np.linspace(2.2, 2.7, 10*len(y6))
zi6 = griddata(x6, y6, z6, xi6, yi6, interp='linear')

x7 = flux_list7
y7 = rad_list7
z7 = helium_list7
np.asarray(x7)
np.asarray(y7)
np.asarray(z7)
xi7 = np.linspace(5, 175, 50*len(x7))
yi7 = np.linspace(1.8, 3.0, 50*len(y7))
zi7 = griddata(x7, y7, z7, xi7, yi7, interp='linear')


"""
#plt.contourf(xi1, yi1, zi1, 15, vmax=1, vmin=0, alpha = 1.0, cmap = cm.Purples)

plt.contourf(xi2, yi2, zi2, np.arange(0, 1.0, .02), alpha = .6, cmap = cm.Reds)
#plt.contourf(xi3, yi3, zi3, np.arange(0, 1.0, .02), alpha = .6, cmap = cm.spring)
#plt.contourf(xi4, yi4, zi4, np.arange(0, 1.0, .02), alpha = .6, cmap = cm.Oranges)
#plt.contourf(xi5, yi5, zi5, np.arange(0, 1.0, .02), alpha = .6, cmap = cm.Purples)
#plt.contourf(xi6, yi6, zi6, np.arange(0, 1.0, .02), alpha = .6, cmap = cm.Greens)
#plt.contourf(xi7, yi7, zi7, np.arange(0, 1.0, .02), alpha = .6, cmap = cm.Blues)

plt.scatter(x2, y2, c=z2, cmap="jet_r")
plt.scatter(x3, y3, c=z3, cmap="jet_r")
plt.scatter(x4, y4, c=z4, cmap="jet_r")
plt.scatter(x5, y5, c=z5, cmap="jet_r")
plt.scatter(x6, y6, c=z6, cmap="jet_r")
plt.scatter(x7, y7, c=z7, cmap="jet_r")
plt.colorbar()

plt.axis([0,200,1.5, 3.0])
plt.gca().invert_xaxis()
plt.show()
#plt.savefig('/Users/isaacmalsky/Desktop/All2.pdf',dpi=400)
# Out:
# /Users/isaacmalsky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning: The griddata function was deprecated in version 2.2.
# <div id='46fb6f7a-c7ee-4e65-bd03-fda200074654'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9a204549bc6d> in <module>()
#     100 plt.scatter(x2, y2, c=z2, cmap="jet_r")
#     101 plt.scatter(x3, y3, c=z3, cmap="jet_r")
# --> 102 plt.scatter(x4, y4, c=z4, cmap="jet_r")
#     103 plt.scatter(x5, y5, c=z5, cmap="jet_r")
#     104 plt.scatter(x6, y6, c=z6, cmap="jet_r")
#
# NameError: name 'x4' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

b = 3.88
c = 2.07
d = 1.043
e = .604
f = .349
g = .236
h = .135

plt.errorbar(b, 1.127 ,yerr=0.028, xerr= 0.22,fmt='.', color='black')
plt.errorbar(c, 1.1 ,yerr=.028, xerr= 0.12,fmt='.', color='black')
plt.errorbar(d, .788 ,yerr=0.02, xerr= 0.06,fmt='.', color='black')
plt.errorbar(e, .915 ,yerr=0.025, xerr= 0.034,fmt='.', color='black')
plt.errorbar(f, 1.052 ,yerr=.026, xerr= .020,fmt='.', color='black')
plt.errorbar(g, 1.154 ,yerr=0.029, xerr= 0.014,fmt='.', color='black')
plt.errorbar(h, .777 ,yerr=0.025, xerr= 0.076,fmt='.', color='black')


#plt.xscale('log')
plt.xlabel('Flux $[S_{earth}]$')
plt.ylabel('Planet Radius $[R_\oplus]$')
plt.title('Irraditaion of the TRAPPIST 1 System')

plt.axis([-.5,4.5,0, 1.75])
plt.gca().invert_xaxis()




plt.savefig('/Users/isaacmalsky/Desktop/Trappist1.png',dpi=300)

plt.show()
